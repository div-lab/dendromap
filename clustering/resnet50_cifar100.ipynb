# %%
from dendromap_data import compute_dendrogram
import json

# %%
# IMPORT INSTANCES
'''
    an instance is to be formatted like
    {
        "filename": string
        "index": int
        "features": int[]
    }
    
    but can also have additional information like
    {
        "filename": string
        "index": int
        "features": int[],
        "true_class": string
        "predicted_class": string
    }

    instances are an array of the instance as formatted above
'''
relative_folder = "./cifar100_model"
predictions_filename = "prediction_results-cifar100-resnet50-test.json"
def import_predictions(filepath):
    data = None
    with open(filepath, "r") as input_file:
        data = json.load(input_file)
    return data

resnet50_cifar100_data = import_predictions(f"{relative_folder}/{predictions_filename}")

instances = resnet50_cifar100_data["test_instances"]
classes = resnet50_cifar100_data["classes"]

# %%
def add_instance_class_info(dendrogram, instances):
    # add predictions information on the leaf nodes
    pred_key = "predicted_class"
    true_key = "true_class"
    for leaf in dendrogram.leaves:
        id = leaf["instance_index"]
        instance = instances[id]

        leaf[pred_key] = instance[pred_key]
        leaf[true_key] = instance[true_key]

# add accuracy and correct count to each node since we have prediction info
def add_acc(instances):
    def _add_acc(node):
        correct_count = 0
        for id in node["cluster"]:
            instance = instances[id]
            correct_count += int(instance["predicted_class"] == instance["true_class"])

        node["correct_count"] = correct_count
        node["accuracy"] = correct_count / len(node["cluster"])
    return _add_acc

def add_prediction_info(dendrogram, instances):
    add_instance_class_info(dendrogram, instances)
    dendrogram.for_each_node(add_acc(instances))

# %%
# compute dendrogram and add extra info
dendrogram = compute_dendrogram(instances, top_similar=100) # necessary step to get the bare minimum dendrogram to work in dendromap
add_prediction_info(dendrogram, instances)
# Out:
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 100 similar
# Adding information to the leaf nodes
# Done!

# %%
print(dendrogram.root.keys())
print(dendrogram.root["accuracy"])
print(dendrogram.root["correct_count"], "over", dendrogram.root["node_count"])
# Out:
# dict_keys(['leaf', 'node_index', 'parent', 'children', 'cluster', 'node_count', 'correct_count', 'accuracy'])
# 0.7625
# 7625 over 10000

# %%
# export the data so we can use it in the interface
with open("../public/cifar100/clusters/cifar100_resnet50.json", "w") as outfile:
    data_export = {"tree": dendrogram.to_json(), "classes": classes}
    json.dump(data_export, outfile)

# %%
# filter instances for each class
def filter_instances_by_class(instances, classes):
    filter_map = {class_name: [] for class_name in classes}
    for instance in instances:
        class_name = instance["true_class"]
        filter_map[class_name].append(instance)
    return filter_map

filtered = filter_instances_by_class(instances, classes)
print(filtered.keys())
for [k, v] in filtered.items():
    print(k, len(v))
# Out:
# dict_keys(['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'])
# apple 100
# aquarium_fish 100
# baby 100
# bear 100
# beaver 100
# bed 100
# bee 100
# beetle 100
# bicycle 100
# bottle 100
# bowl 100
# boy 100
# bridge 100
# bus 100
# butterfly 100
# camel 100
# can 100
# castle 100
# caterpillar 100
# cattle 100
# chair 100
# chimpanzee 100
# clock 100
# cloud 100
# cockroach 100
# couch 100
# crab 100
# crocodile 100
# cup 100
# dinosaur 100
# dolphin 100
# elephant 100
# flatfish 100
# forest 100
# fox 100
# girl 100
# hamster 100
# house 100
# kangaroo 100
# keyboard 100
# lamp 100
# lawn_mower 100
# leopard 100
# lion 100
# lizard 100
# lobster 100
# man 100
# maple_tree 100
# motorcycle 100
# mountain 100
# mouse 100
# mushroom 100
# oak_tree 100
# orange 100
# orchid 100
# otter 100
# palm_tree 100
# pear 100
# pickup_truck 100
# pine_tree 100
# plain 100
# plate 100
# poppy 100
# porcupine 100
# possum 100
# rabbit 100
# raccoon 100
# ray 100
# road 100
# rocket 100
# rose 100
# sea 100
# seal 100
# shark 100
# shrew 100
# skunk 100
# skyscraper 100
# snail 100
# snake 100
# spider 100
# squirrel 100
# streetcar 100
# sunflower 100
# sweet_pepper 100
# table 100
# tank 100
# telephone 100
# television 100
# tiger 100
# tractor 100
# train 100
# trout 100
# tulip 100
# turtle 100
# wardrobe 100
# whale 100
# willow_tree 100
# wolf 100
# woman 100
# worm 100

# %%
# compute and export dendrogram for each filtered class
data_export = {}
for [class_name, filtered_instances] in filtered.items():
    print(f"\nCOMPUTING ON { class_name }")
    filtered_dendrogram = compute_dendrogram(filtered_instances, top_similar=25)
    add_prediction_info(filtered_dendrogram, filtered_instances)
    data_export[class_name] = filtered_dendrogram.to_json()

with open("../public/cifar100/clusters/cifar100_resnet50_classes.json", "w") as outfile:
    data_export["classes"] = classes
    json.dump(data_export, outfile)
# Out:
# COMPUTING ON apple
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON aquarium_fish
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON baby
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON bear
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON beaver
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON bed
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON bee
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON beetle
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON bicycle
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON bottle
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON bowl
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON boy
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON bridge
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON bus
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON butterfly
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON camel
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON can
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON castle
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON caterpillar
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON cattle
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON chair
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON chimpanzee
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON clock
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON cloud
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON cockroach
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON couch
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON crab
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON crocodile
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON cup
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON dinosaur
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON dolphin
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON elephant
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON flatfish
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON forest
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON fox
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON girl
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON hamster
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON house
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON kangaroo
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON keyboard
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON lamp
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON lawn_mower
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON leopard
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON lion
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON lizard
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON lobster
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON man
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON maple_tree
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON motorcycle
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON mountain
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON mouse
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON mushroom
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON oak_tree
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON orange
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON orchid
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON otter
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON palm_tree
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON pear
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON pickup_truck
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON pine_tree
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON plain
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON plate
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON poppy
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON porcupine
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON possum
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON rabbit
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON raccoon
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON ray
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON road
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON rocket
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON rose
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON sea
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON seal
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON shark
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON shrew
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON skunk
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON skyscraper
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON snail
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON snake
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON spider
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON squirrel
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON streetcar
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON sunflower
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON sweet_pepper
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON table
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON tank
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON telephone
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON television
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON tiger
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON tractor
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON train
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON trout
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON tulip
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON turtle
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON wardrobe
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON whale
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON willow_tree
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON wolf
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON woman
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
#
# COMPUTING ON worm
# Extracting Features
# Agglomerative Clustering
# Constructing Dendrogram
# Computing top 25 similar
# Adding information to the leaf nodes
# Done!
